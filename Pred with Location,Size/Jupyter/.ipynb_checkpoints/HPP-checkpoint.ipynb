# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.utils.validation import check_is_fitted

# %%
def wrangle(filepath):
    df = pd.read_csv(filepath)
    
    mask_india = df["ADDRESS"].str.contains("Mumbai")
    mask_bhk = df["BHK_OR_RK"] == "BHK"
    mask_price = df["TARGET(PRICE_IN_LACS)"] < 1_000
    
    df = df[mask_india & mask_bhk & mask_price]
    
    return df

# %%
df = wrangle("/home/d3lia/Development/DataScience/House Price Prediction in India/Jupyter/Participants_Data_HPP/Train.csv")
df.head()
# Out:
#     POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 23     Dealer                   0     0        1       BHK   630.000630
# 43     Dealer                   0     1        3       BHK  1274.924779
# 66     Dealer                   0     1        3       BHK  1038.883942
# 84     Dealer                   0     1        2       BHK  1004.932182
# 131    Dealer                   0     1        2       BHK  1294.016156
#
#      READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# 23               1       1  Bandra (West),Mumbai  19.054440  72.840560
# 43               1       1          Marol,Mumbai  22.803593  83.755013
# 66               1       1          Powai,Mumbai  19.120000  72.910000
# 84               1       1     New Panvel,Mumbai  18.966114  73.148278
# 131              1       1     4 Bunglows,Mumbai  19.128324  72.825408
#
#      TARGET(PRICE_IN_LACS)
# 23                   300.0
# 43                   250.0
# 66                   280.0
# 84                    81.5
# 131                  330.0

# %%
plt.hist(df["SQUARE_FT"])
plt.xlabel("Area [sq feet]")
plt.title("Distribution of BHK Prices")
# Out:
# Text(0.5, 1.0, 'Distribution of BHK Prices')

# %%
df.describe()["SQUARE_FT"]
# Out:
# count    1978.000000
# mean     1063.460944
# std       516.203018
# min       225.004536
# 25%       683.400048
# 50%      1000.000000
# 75%      1250.000000
# max      5670.578927
# Name: SQUARE_FT, dtype: float64

# %%
plt.scatter(x=df["SQUARE_FT"], y=df["TARGET(PRICE_IN_LACS)"])
plt.xlabel("Area [sq feet]")
plt.ylabel("Price [LACS]")
plt.title("Mumbai: Price vs Area");

# %%
correlation = df["SQUARE_FT"].corr(df["TARGET(PRICE_IN_LACS)"])
print(correlation)
# Out:
# 0.7163781008635076

# %%
feature = ["SQUARE_FT"]
X_train = df[feature]
X_train.shape
# Out:
# (1978, 1)

# %%
target = "TARGET(PRICE_IN_LACS)"
y_train = df[target]
y_train.shape
# Out:
# (1978,)

# %%
y_mean = y_train.mean()
y_mean
# Out:
# 170.5484833164813

# %%
y_pred_baseline = [y_mean] * len(y_train)
y_pred_baseline[:5]
# Out:
# [170.5484833164813,
#  170.5484833164813,
#  170.5484833164813,
#  170.5484833164813,
#  170.5484833164813]

# %%
plt.plot(X_train.values, y_pred_baseline, color="orange", label="Baseline Model")
plt.scatter(X_train.values, y_train)
plt.xlabel("Area [sq feet]")
plt.ylabel("Price [LACS]")
plt.title("Mumbai: Price vs Area")
plt.legend();

# %%
mae_baseline = mean_absolute_error(y_train, y_pred_baseline)
print("Mean BHK Price", round(y_mean, 2))
print("Baseline MAE:", round(mae_baseline, 2))
# Out:
# Mean BHK Price 170.55
# Baseline MAE: 104.9

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_training = model.predict(X_train)
y_pred_training[:5]
# Out:
# array([ 77.79964619, 215.7960508 , 165.2896666 , 158.02490404,
#        219.88109148])

# %%
mae_training = mean_absolute_error(y_train, y_pred_training)
print("Training MAE:", round(mae_training, 2))
# Out:
# Training MAE: 70.93

# %%
X_test = pd.read_csv("/home/d3lia/Development/DataScience/House Price Prediction in India/Jupyter/Participants_Data_HPP/Test.csv")
y_pred_test = pd.Series(model.predict(X_test))
y_pred_test.head()
# Out:
# /home/d3lia/.local/lib/python3.8/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - ADDRESS
# - BHK_NO.
# - BHK_OR_RK
# - LATITUDE
# - LONGITUDE
# - ...
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [31], line 2
#       1 X_test = pd.read_csv("/home/d3lia/Development/DataScience/House Price Prediction in India/Jupyter/Participants_Data_HPP/Test.csv")
# ----> 2 y_pred_test = pd.Series(model.predict(X_test))
#       3 y_pred_test.head()
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Owner'
